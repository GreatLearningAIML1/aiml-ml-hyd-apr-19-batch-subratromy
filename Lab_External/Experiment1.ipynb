# %%
import pandas as pd
df=pd.read_csv("HR-1.txt",delimiter="\t")
df
# Out:
#      Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0           Ind1       Yes   41               1       1102           1
# 1           Ind2        No   49               2        279           2
# 2           Ind3       Yes   37               1       1373           2
# 3           Ind4        No   33               2       1392           2
# 4           Ind5        No   27               1        591           2
# 5           Ind6        No   32               2       1005           2
# 6           Ind7        No   59               1       1324           2
# 7           Ind8        No   30               1       1358           2
# 8           Ind9        No   38               2        216           2
# 9          Ind10        No   36               1       1299           2
# 10         Ind11        No   35               1        809           2
# 11         Ind12        No   29               1        153           2
# ...

# %%
g = df.groupby("Attrition")

# %%
for Attrition, attrition_yes in g:
    print(Attrition)
    print(attrition_yes)
# Out:
# No
#      Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 1           Ind2        No   49               2        279           2
# 3           Ind4        No   33               2       1392           2
# 4           Ind5        No   27               1        591           2
# 5           Ind6        No   32               2       1005           2
# 6           Ind7        No   59               1       1324           2
# 7           Ind8        No   30               1       1358           2
# 8           Ind9        No   38               2        216           2
# 9          Ind10        No   36               1       1299           2
# 10         Ind11        No   35               1        809           2
# 11         Ind12        No   29               1        153           2
# 12         Ind13        No   31               1        670           2
# 13         Ind14        No   34               1       1346           2
# ...

# %%
g.get_group("Yes")
# Out:
#      Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0           Ind1       Yes   41               1       1102           1
# 2           Ind3       Yes   37               1       1373           2
# 14         Ind15       Yes   28               1        103           2
# 21         Ind22       Yes   36               1       1218           1
# 24         Ind25       Yes   34               1        699           2
# 26         Ind27       Yes   32               2       1125           2
# 33         Ind34       Yes   39               1        895           1
# 34         Ind35       Yes   24               1        813           2
# 36         Ind37       Yes   50               1        869           1
# 42         Ind43       Yes   26               1       1357           2
# 45         Ind46       Yes   41               1       1360           2
# 50         Ind51       Yes   48               1        626           2
# ...

# %%
g.get_group("No")
# Out:
#      Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 1           Ind2        No   49               2        279           2
# 3           Ind4        No   33               2       1392           2
# 4           Ind5        No   27               1        591           2
# 5           Ind6        No   32               2       1005           2
# 6           Ind7        No   59               1       1324           2
# 7           Ind8        No   30               1       1358           2
# 8           Ind9        No   38               2        216           2
# 9          Ind10        No   36               1       1299           2
# 10         Ind11        No   35               1        809           2
# 11         Ind12        No   29               1        153           2
# 12         Ind13        No   31               1        670           2
# 13         Ind14        No   34               1       1346           2
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.hist(df["Attrition"])
plt.xlabel("Attrition")
#plt.ylabel("Age")
plt.title("DF")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
y = np.arange(1,11)
plt.plot(y)
plt.xlabel("Numbers")
plt.show()
